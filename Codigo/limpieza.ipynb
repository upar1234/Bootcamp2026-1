# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('C:\\Universidad\\Sistemas\\Bootcamp2026-1\\Documentos\\MES_1225.xlsx')

# %%
df.head(20)
# Out:
#    The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  \
# 0                                                 NaN
# 1                                               False
# 2   In particular, external dissemination of any I...
# 3   Please contact us at stats@iea.org if you have...
# 4                                        Last update:
# 5   This notice, and any copyright or sourcing sta...
# 6                                                 NaN
# 7                                             Country
# 8                                           Australia
# 9                                           Australia
# 10                                          Australia
# 11                                          Australia
# 12                                          Australia
# 13                                          Australia
# 14                                          Australia
# ...

# %%
df = df.drop(df.index[0:7], axis = 0)
df.reset_index(drop = True)
df
# Out:
#        The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  \
# 7                                                 Country
# 8                                               Australia
# 9                                               Australia
# 10                                              Australia
# 11                                              Australia
# ...                                                   ...
# 158181                                          IEA Total
# 158182                                          IEA Total
# 158183                                          IEA Total
# 158184                                          IEA Total
# 158185                                          IEA Total
#
#            Unnamed: 1                      Unnamed: 2  \
# 7                Time                         Balance
# 8       December 2025      Net Electricity Production
# ...

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158179 entries, 7 to 158185
# Data columns (total 6 columns):
#  #   Column                                                                                                                                                 Non-Null Count   Dtype
# ---  ------                                                                                                                                                 --------------   -----
#  0   The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  158179 non-null  object
#  1   Unnamed: 1                                                                                                                                             158179 non-null  object
# ...

# %%
df.columns = df.iloc[0]
df.drop(7, inplace=True)

# %%
df.reset_index(drop = True)
df.columns.name = None

# %%
nulos = df.isnull()
nulos = df[nulos['Value'] == True]
nulos
# Out:
#           Country            Time  Balance                           Product  \
# 102    Costa Rica   December 2025  Remarks  Data is estimated for this month
# 249       Iceland   December 2025  Remarks  Data is estimated for this month
# 292         Japan   December 2025  Remarks  Data is estimated for this month
# 702     Argentina   December 2025  Remarks  Data is estimated for this month
# 915    Costa Rica   November 2025  Remarks  Data is estimated for this month
# 1062      Iceland   November 2025  Remarks  Data is estimated for this month
# 1105        Japan   November 2025  Remarks  Data is estimated for this month
# 1514    Argentina   November 2025  Remarks  Data is estimated for this month
# 1726   Costa Rica    October 2025  Remarks  Data is estimated for this month
# 1874      Iceland    October 2025  Remarks  Data is estimated for this month
# 2326    Argentina    October 2025  Remarks  Data is estimated for this month
# ...

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Country    0
# Time       0
# Balance    0
# Product    0
# Value      0
# Unit       0
# dtype: int64

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Extraer el número del mes (1 al 12)

df['Month'] = df['Time'].dt.month
# Extraer el año (ej. 2026)
df['Year'] = df['Time'].dt.year

colombia = df[df['Country'] == 'Colombia']
colombia.reset_index(drop = True)
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_16280\1458930523.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
#        Country       Time                         Balance  \
# 0     Colombia 2025-12-01      Net Electricity Production
# 1     Colombia 2025-12-01      Net Electricity Production
# 2     Colombia 2025-12-01      Net Electricity Production
# 3     Colombia 2025-12-01      Net Electricity Production
# 4     Colombia 2025-12-01      Net Electricity Production
# ...        ...        ...                             ...
# 2341  Colombia 2014-01-01                   Total Imports
# 2342  Colombia 2014-01-01                   Total Exports
# 2343  Colombia 2014-01-01             Distribution Losses
# 2344  Colombia 2014-01-01  Final Consumption (Calculated)
# ...

# %%
from IPython.display import FileLink

# 1. Guardas el DataFrame como CSV
colombia.to_csv('colombia.csv', index=False)

# 2. Creas un enlace de descarga interactivo
FileLink('colombia.csv')
# Out:
# c:\Universidad\Sistemas\Bootcamp2026-1\Codigo\colombia.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158119 entries, 8 to 158185
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Country  158119 non-null  object
#  1   Time     158119 non-null  datetime64[ns]
#  2   Balance  158119 non-null  object
#  3   Product  158119 non-null  object
#  4   Value    158119 non-null  object
#  5   Unit     158119 non-null  object
#  6   Month    158119 non-null  int32
#  7   Year     158119 non-null  int32
# dtypes: datetime64[ns](1), int32(2), object(5)
# memory usage: 9.7+ MB

# %%
productos = colombia['Product'].value_counts()
productos
# Out:
# Product
# Electricity                                          768
# Hydro                                                144
# Total Combustible Fuels                              144
# Coal, Peat and Manufactured Gases                    144
# Oil and Petroleum Products                           144
# Natural Gas                                          144
# Combustible Renewables                               144
# Solar                                                144
# Total Renewables (Hydro, Geo, Solar, Wind, Other)    144
# Wind                                                 140
# Not Specified                                         92
# Other Combustible Non-Renewables                      50
# Nuclear                                               48
# Geothermal                                            48
# Other Renewables                                      48
# Name: count, dtype: int64

# %%
# Cuenta los registros y lo convierte en una tabla organizada
resumen_tipos = colombia['Product'].value_counts().reset_index()

# Opcional: Le cambiamos el nombre a las columnas para que sea más claro
resumen_tipos.columns = ['Tipo de Proyecto', 'Cantidad de Registros']

# Mostramos el resultado
print(resumen_tipos)
# Out:
#                                      Tipo de Proyecto  Cantidad de Registros
# 0                                         Electricity                    768
# 1                                               Hydro                    144
# 2                             Total Combustible Fuels                    144
# 3                   Coal, Peat and Manufactured Gases                    144
# 4                          Oil and Petroleum Products                    144
# 5                                         Natural Gas                    144
# 6                              Combustible Renewables                    144
# 7                                               Solar                    144
# 8   Total Renewables (Hydro, Geo, Solar, Wind, Other)                    144
# 9                                                Wind                    140
# 10                                      Not Specified                     92
# ...

# %%
# Cuenta los registros y lo convierte en una tabla organizada
resumen_años = colombia['Year'].value_counts().reset_index()

# Opcional: Le cambiamos el nombre a las columnas para que sea más claro
resumen_años.columns = ['Año', 'Cantidad de Registros por año']

# Mostramos el resultado
print(resumen_años)
# Out:
#      Año  Cantidad de Registros por año
# 0   2018                            240
# 1   2019                            240
# 2   2020                            240
# 3   2021                            240
# 4   2022                            182
# 5   2024                            180
# 6   2023                            180
# 7   2025                            176
# 8   2016                            168
# 9   2015                            168
# 10  2014                            168
# 11  2017                            164

# %%
# Cuenta los registros y lo convierte en una tabla organizada
resumen_años = colombia['Month'].value_counts().reset_index()

# Opcional: Le cambiamos el nombre a las columnas para que sea más claro
resumen_años.columns = ['Mes', 'Cantidad de Registros por mes']

# Mostramos el resultado
print(resumen_años)
# Out:
#     Mes  Cantidad de Registros por mes
# 0     4                            196
# 1     5                            196
# 2     6                            196
# 3     8                            196
# 4     1                            196
# 5     2                            196
# 6    11                            195
# 7    12                            195
# 8     9                            195
# 9    10                            195
# 10    7                            195
# 11    3                            195

# %%
import matplotlib.pyplot as plt
# Contar energia generada por cada tipo de proyecto
colombia = colombia[colombia['Product'] != 'Electricity']
colombia
# Out:
#          Country       Time                     Balance  \
# 89      Colombia 2025-12-01  Net Electricity Production
# 90      Colombia 2025-12-01  Net Electricity Production
# 91      Colombia 2025-12-01  Net Electricity Production
# 92      Colombia 2025-12-01  Net Electricity Production
# 93      Colombia 2025-12-01  Net Electricity Production
# ...          ...        ...                         ...
# 124341  Colombia 2014-01-01  Net Electricity Production
# 124342  Colombia 2014-01-01  Net Electricity Production
# 124343  Colombia 2014-01-01  Net Electricity Production
# 124344  Colombia 2014-01-01  Net Electricity Production
# 124349  Colombia 2014-01-01  Net Electricity Production
#
#                                                   Product      Value Unit  \
# 89                                                  Hydro  5530.6545  GWh
# 90                                Total Combustible Fuels  1764.6682  GWh
# ...

# %%
energia_por_tipo = colombia.groupby('Product')['Value'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.bar(energia_por_tipo['Product'], energia_por_tipo['Value'])
plt.xlabel('Tipo de Proyecto')
plt.ylabel('Energía Generada')
plt.title('Energía Generada por Tipo de Proyecto')
plt.xticks(rotation=45)
plt.show()
