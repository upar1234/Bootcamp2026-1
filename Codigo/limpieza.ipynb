# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('C:/Users/Alejandro/OneDrive/Documents/GitHub/Bootcamp2026-1/Documentos/MES_1225.xlsx')

# %%
df.head(20)
# Out:
#    The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  \
# 0                                                 NaN
# 1                                               False
# 2   In particular, external dissemination of any I...
# 3   Please contact us at stats@iea.org if you have...
# 4                                        Last update:
# 5   This notice, and any copyright or sourcing sta...
# 6                                                 NaN
# 7                                             Country
# 8                                           Australia
# 9                                           Australia
# 10                                          Australia
# 11                                          Australia
# 12                                          Australia
# 13                                          Australia
# 14                                          Australia
# 15                                          Australia
# 16                                          Australia
# 17                                          Australia
# 18                                          Australia
# 19                                          Australia
#
#        Unnamed: 1                      Unnamed: 2  \
# 0             NaN                             NaN
# 1             NaN                             NaN
# 2             NaN                             NaN
# 3             NaN                             NaN
# 4   15 March 2026                             NaN
# 5             NaN                             NaN
# 6             NaN                             NaN
# 7            Time                         Balance
# 8   December 2025      Net Electricity Production
# 9   December 2025      Net Electricity Production
# 10  December 2025      Net Electricity Production
# 11  December 2025      Net Electricity Production
# 12  December 2025      Net Electricity Production
# 13  December 2025      Net Electricity Production
# 14  December 2025      Net Electricity Production
# 15  December 2025      Net Electricity Production
# 16  December 2025      Net Electricity Production
# 17  December 2025         Used for pumped storage
# 18  December 2025             Distribution Losses
# 19  December 2025  Final Consumption (Calculated)
#
#                                            Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                                                 NaN         NaN        NaN
# 1                                                 NaN         NaN        NaN
# 2                                                 NaN         NaN        NaN
# 3                                                 NaN         NaN        NaN
# 4                                                 NaN         NaN        NaN
# 5                                                 NaN         NaN        NaN
# 6                                                 NaN         NaN        NaN
# 7                                             Product       Value       Unit
# 8                                         Electricity  23360.4375        GWh
# 9                                               Hydro    932.8479        GWh
# 10                            Total Combustible Fuels  12210.7489        GWh
# 11                  Coal, Peat and Manufactured Gases   8782.6749        GWh
# 12                         Oil and Petroleum Products    293.4672        GWh
# 13                                        Natural Gas   2948.0199        GWh
# 14                             Combustible Renewables    186.5869        GWh
# 15                                              Solar   6688.7891        GWh
# 16  Total Renewables (Hydro, Geo, Solar, Wind, Other)  11336.2756        GWh
# 17                                        Electricity     80.4632        GWh
# 18                                        Electricity     1135.38        GWh
# 19                                        Electricity  22144.5943        GWh

# %%
df = df.drop(df.index[0:7], axis = 0)
df.reset_index(drop = True)
# Out:
#        The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview  \
# 0                                                 Country
# 1                                               Australia
# 2                                               Australia
# 3                                               Australia
# 4                                               Australia
# ...                                                   ...
# 158174                                          IEA Total
# 158175                                          IEA Total
# 158176                                          IEA Total
# 158177                                          IEA Total
# 158178                                          IEA Total
#
#            Unnamed: 1                      Unnamed: 2  \
# 0                Time                         Balance
# 1       December 2025      Net Electricity Production
# 2       December 2025      Net Electricity Production
# 3       December 2025      Net Electricity Production
# 4       December 2025      Net Electricity Production
# ...               ...                             ...
# 158174   January 2010                   Total Exports
# 158175   January 2010         Used for pumped storage
# 158176   January 2010             Distribution Losses
# 158177   January 2010  Final Consumption (Calculated)
# 158178   January 2010      Net Electricity Production
#
#                                Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                                 Product       Value       Unit
# 1                             Electricity  23360.4375        GWh
# 2                                   Hydro    932.8479        GWh
# 3                 Total Combustible Fuels  12210.7489        GWh
# 4       Coal, Peat and Manufactured Gases   8782.6749        GWh
# ...                                   ...         ...        ...
# 158174                        Electricity   32372.583        GWh
# 158175                        Electricity    6869.253        GWh
# 158176                        Electricity   62000.733        GWh
# 158177                        Electricity  877213.615        GWh
# 158178                               Wind   21659.612        GWh
#
# [158179 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['The Monthly electricity data explorer and the main highlights are available here: https://www.iea.org/reports/monthly-electricity-statistics-overview',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
df.columns = df.iloc[0]
df.drop(7, inplace=True)

# %%
df.reset_index(drop = True)
df.columns.name = None

# %%
df.columns
# Out:
# Index(['Country', 'Time', 'Balance', 'Product', 'Value', 'Unit'], dtype='object')

# %%
nulos = df.isnull()
nulos.sum()
# Out:
# Country    0
# Time       0
# Balance    0
# Product    0
# Value      0
# Unit       0
# dtype: int64

# %%
colombia = df[df['Country'] == 'Colombia']
colombia.reset_index(drop = True)
# Out:
#        Country           Time                         Balance  \
# 0     Colombia  December 2025      Net Electricity Production
# 1     Colombia  December 2025      Net Electricity Production
# 2     Colombia  December 2025      Net Electricity Production
# 3     Colombia  December 2025      Net Electricity Production
# 4     Colombia  December 2025      Net Electricity Production
# ...        ...            ...                             ...
# 2341  Colombia   January 2014                   Total Imports
# 2342  Colombia   January 2014                   Total Exports
# 2343  Colombia   January 2014             Distribution Losses
# 2344  Colombia   January 2014  Final Consumption (Calculated)
# 2345  Colombia   January 2014      Net Electricity Production
#
#                                 Product      Value Unit
# 0                           Electricity  7794.9781  GWh
# 1                                 Hydro  5530.6545  GWh
# 2               Total Combustible Fuels  1764.6682  GWh
# 3     Coal, Peat and Manufactured Gases   483.3555  GWh
# 4            Oil and Petroleum Products   287.5943  GWh
# ...                                 ...        ...  ...
# 2341                        Electricity      0.021  GWh
# 2342                        Electricity    146.888  GWh
# 2343                        Electricity    536.164  GWh
# 2344                        Electricity   5019.684  GWh
# 2345                               Wind      5.648  GWh
#
# [2346 rows x 6 columns]

# %%
productos = colombia[colombia['Product']].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 productos = df[colombia['Product']].sum()
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1206, in Series._get_with(self, key)
#    1203         return self.iloc[key]
#    1205 # handle the dup indexing case GH#4246
# -> 1206 return self.loc[key]
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Alejandro\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Electricity', 'Hydro', 'Total Combustible Fuels',\n       'Coal, Peat and Manufactured Gases', 'Oil and Petroleum Products',\n       'Natural Gas', 'Combustible Renewables', 'Solar',\n       'Total Renewables (Hydro, Geo, Solar, Wind, Other)', 'Electricity',\n       ...\n       'Oil and Petroleum Products', 'Natural Gas', 'Combustible Renewables',\n       'Solar', 'Total Renewables (Hydro, Geo, Solar, Wind, Other)',\n       'Electricity', 'Electricity', 'Electricity', 'Electricity', 'Wind'],\n      dtype='object', length=2346)] are in the [index]"
