# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
archivo='../Documentos/Meta_FNCER__Incorporar_en_la_matriz_energética_nueva_capacidad_instalada_a_partir_de_Fuentes_No_Convencionales_de_Energía_Renovable_-_FNCER_20260326.csv'
df=pd.read_csv(archivo)
df
# Out:
#                              Proyecto    Tipo  Capacidad     Departamento  \
# 0                           JEPIRACHI  Eólico      18.42       LA GUAJIRA
# 1            AUTOG CELSIA SOLAR YUMBO   Solar       9.80  VALLE DEL CAUCA
# 2                CELSIA SOLAR BOLIVAR   Solar       8.06          BOLÍVAR
# 3    EL PASO SOLAR (ENEL GREEN POWER)   Solar      67.00            CESAR
# 4                  SOLAR CASTILLA ECP   Solar      20.00             META
# ..                                ...     ...        ...              ...
# 153                    BUGA 1 PARTE 2   Solar       5.94  VALLE DEL CAUCA
# 154                    BUGA 1 PARTE 1   Solar       3.96  VALLE DEL CAUCA
# 155                     REFINERÍA GRB   Solar      21.00        SANTANDER
# 156       EMSA GD Y AG (34 Proyectos)   Solar       1.90             META
# 157      ENELAR GD Y AG (4 Proyectos)   Solar       0.11           ARAUCA
#
#              Municipio  Código Departamento  Código Municipio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Proyecto                  158 non-null    str
#  1   Tipo                      158 non-null    str
#  2   Capacidad                 158 non-null    float64
#  3   Departamento              158 non-null    str
#  4   Municipio                 158 non-null    str
#  5   Código Departamento       158 non-null    int64
#  6   Código Municipio          158 non-null    int64
#  7   Fecha estimada FPO        158 non-null    str
#  8   Energía [kWh/día]         158 non-null    str
#  9   Usuarios                  158 non-null    str
#  10  Inversión estimada [COP]  158 non-null    str
#  11  Empleos estimados         158 non-null    str
#  12  Emisiones CO2 [Ton/año]   158 non-null    str
# dtypes: float64(1), int64(2), str(10)
# memory usage: 31.5 KB

# %%
# Cuenta los registros y lo convierte en una tabla organizada
resumen_tipos = df['Tipo'].value_counts().reset_index()

# Opcional: Le cambiamos el nombre a las columnas para que sea más claro
resumen_tipos.columns = ['Tipo de Proyecto', 'Cantidad de Registros']

# Mostramos el resultado
print(resumen_tipos)
# Out:
#   Tipo de Proyecto  Cantidad de Registros
# 0            Solar                    145
# 1           Eólico                     13
